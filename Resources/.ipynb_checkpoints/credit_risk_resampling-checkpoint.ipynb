# %% [markdown]
# # Credit Risk Resampling Techniques -Supervised Machine Learning

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# import dependencies needed for challenge
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter
from collections import Counter
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import RandomOverSampler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import ClusterCentroids
from imblearn.combine import SMOTEENN

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
columns = [
    "loan_amnt", "int_rate", "installment", "home_ownership",
    "annual_inc", "verification_status", "issue_d", "loan_status",
    "pymnt_plan", "dti", "delinq_2yrs", "inq_last_6mths",
    "open_acc", "pub_rec", "revol_bal", "total_acc",
    "initial_list_status", "out_prncp", "out_prncp_inv", "total_pymnt",
    "total_pymnt_inv", "total_rec_prncp", "total_rec_int", "total_rec_late_fee",
    "recoveries", "collection_recovery_fee", "last_pymnt_amnt", "next_pymnt_d",
    "collections_12_mths_ex_med", "policy_code", "application_type", "acc_now_delinq",
    "tot_coll_amt", "tot_cur_bal", "open_acc_6m", "open_act_il",
    "open_il_12m", "open_il_24m", "mths_since_rcnt_il", "total_bal_il",
    "il_util", "open_rv_12m", "open_rv_24m", "max_bal_bc",
    "all_util", "total_rev_hi_lim", "inq_fi", "total_cu_tl",
    "inq_last_12m", "acc_open_past_24mths", "avg_cur_bal", "bc_open_to_buy",
    "bc_util", "chargeoff_within_12_mths", "delinq_amnt", "mo_sin_old_il_acct",
    "mo_sin_old_rev_tl_op", "mo_sin_rcnt_rev_tl_op", "mo_sin_rcnt_tl", "mort_acc",
    "mths_since_recent_bc", "mths_since_recent_inq", "num_accts_ever_120_pd", "num_actv_bc_tl",
    "num_actv_rev_tl", "num_bc_sats", "num_bc_tl", "num_il_tl",
    "num_op_rev_tl", "num_rev_accts", "num_rev_tl_bal_gt_0",
    "num_sats", "num_tl_120dpd_2m", "num_tl_30dpd", "num_tl_90g_dpd_24m",
    "num_tl_op_past_12m", "pct_tl_nvr_dlq", "percent_bc_gt_75", "pub_rec_bankruptcies",
    "tax_liens", "tot_hi_cred_lim", "total_bal_ex_mort", "total_bc_limit",
    "total_il_high_credit_limit", "hardship_flag", "debt_settlement_flag"
]

target = ["loan_status"]

# %%
# Load the data
file_path = Path('LoanStats_2019Q1.csv')
df = pd.read_csv(file_path, skiprows=1)[:-2]
df.head()
# Out:
#     id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  NaN        NaN    20000.0      20000.0          20000.0   60 months
# 1  NaN        NaN    21225.0      21225.0          21225.0   60 months
# 2  NaN        NaN     5000.0       5000.0           5000.0   36 months
# 3  NaN        NaN    20000.0      20000.0          20000.0   36 months
# 4  NaN        NaN    12000.0      12000.0          12000.0   60 months
#
#   int_rate  installment grade sub_grade  ...  \
# 0   17.19%       499.10     C        C5  ...
# 1   14.74%       502.05     C        C2  ...
# 2   17.97%       180.69     D        D1  ...
# 3    8.19%       628.49     A        A4  ...
# 4   15.57%       289.09     C        C3  ...
#
#   orig_projected_additional_accrued_interest hardship_payoff_balance_amount  \
# 0                                        NaN                            NaN
# 1                                        NaN                            NaN
# ...

# %%
df = df.loc[:, columns].copy()

# Drop the null in columns where all values are null
df = df.dropna(axis='columns', how='all')

# Drop the null rows
df = df.dropna()

# %%
df.tail(5)
# Out:
#         loan_amnt int_rate  installment home_ownership  annual_inc  \
# 115661    10000.0   15.02%       346.76           RENT     26000.0
# 115663    12000.0   27.27%       368.37           RENT     63000.0
# 115664     5000.0   19.92%       185.62       MORTGAGE     52000.0
# 115669    40000.0    6.46%      1225.24       MORTGAGE    520000.0
# 115673    16000.0   11.31%       350.36       MORTGAGE     72000.0
#
#        verification_status   issue_d loan_status pymnt_plan    dti  ...  \
# 115661     Source Verified  Jan-2019     Current          n   9.60  ...
# 115663        Not Verified  Jan-2019     Current          n  29.07  ...
# 115664     Source Verified  Jan-2019     Current          n  14.86  ...
# 115669            Verified  Jan-2019     Current          n   9.96  ...
# 115673            Verified  Jan-2019     Current          n   7.02  ...
#
#         pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# ...

# %%
# Remove the `Issued` loan status we only need loan data that is not yet issued
issued_mask = df['loan_status'] != 'Issued'
df = df.loc[issued_mask]

# %%
df.head(5)
# Out:
#      loan_amnt int_rate  installment home_ownership  annual_inc  \
# 93     10500.0   17.19%       375.35           RENT     66000.0
# 99     25000.0   20.00%       929.09       MORTGAGE    105000.0
# 132    20000.0   20.00%       529.88       MORTGAGE     56000.0
# 133    10000.0   16.40%       353.55           RENT     92000.0
# 140    22000.0   14.74%       520.39       MORTGAGE     52000.0
#
#     verification_status   issue_d loan_status pymnt_plan    dti  ...  \
# 93      Source Verified  Mar-2019     Current          n  27.24  ...
# 99             Verified  Mar-2019     Current          n  20.23  ...
# 132            Verified  Mar-2019     Current          n  24.26  ...
# 133            Verified  Mar-2019     Current          n  31.44  ...
# 140        Not Verified  Mar-2019     Current          n  18.76  ...
#
#      pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 93             85.7             100.0                   0.0        0.0
# ...

# %%
# convert interest rate to numerical
df['int_rate'] = df['int_rate'].str.replace('%', '')
df['int_rate'] = df['int_rate'].astype('float') / 100

# %%
df.dtypes
# Out:
# loan_amnt                     float64
# int_rate                      float64
# installment                   float64
# home_ownership                 object
# annual_inc                    float64
#                                ...
# total_bal_ex_mort             float64
# total_bc_limit                float64
# total_il_high_credit_limit    float64
# hardship_flag                  object
# debt_settlement_flag           object
# Length: 86, dtype: object

# %%
df.head(5)
# Out:
#      loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 93     10500.0    0.1719       375.35           RENT     66000.0
# 99     25000.0    0.2000       929.09       MORTGAGE    105000.0
# 132    20000.0    0.2000       529.88       MORTGAGE     56000.0
# 133    10000.0    0.1640       353.55           RENT     92000.0
# 140    22000.0    0.1474       520.39       MORTGAGE     52000.0
#
#     verification_status   issue_d loan_status pymnt_plan    dti  ...  \
# 93      Source Verified  Mar-2019     Current          n  27.24  ...
# 99             Verified  Mar-2019     Current          n  20.23  ...
# 132            Verified  Mar-2019     Current          n  24.26  ...
# 133            Verified  Mar-2019     Current          n  31.44  ...
# 140        Not Verified  Mar-2019     Current          n  18.76  ...
#
#      pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 93             85.7             100.0                   0.0        0.0
# ...

# %%
df.head(5)
# Out:
#      loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 93     10500.0    0.1719       375.35           RENT     66000.0
# 99     25000.0    0.2000       929.09       MORTGAGE    105000.0
# 132    20000.0    0.2000       529.88       MORTGAGE     56000.0
# 133    10000.0    0.1640       353.55           RENT     92000.0
# 140    22000.0    0.1474       520.39       MORTGAGE     52000.0
#
#     verification_status   issue_d loan_status pymnt_plan    dti  ...  \
# 93      Source Verified  Mar-2019     Current          n  27.24  ...
# 99             Verified  Mar-2019     Current          n  20.23  ...
# 132            Verified  Mar-2019     Current          n  24.26  ...
# 133            Verified  Mar-2019     Current          n  31.44  ...
# 140        Not Verified  Mar-2019     Current          n  18.76  ...
#
#      pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 93             85.7             100.0                   0.0        0.0
# ...

# %%
# Convert the target column values to low_risk and high_risk based on their values
x = {'Current': 'low_risk'}   
df = df.replace(x)

x = dict.fromkeys(['Late (31-120 days)', 'Late (16-30 days)', 'Default', 'In Grace Period'], 'high_risk')    
df = df.replace(x)

df.reset_index(inplace=True, drop=True)

df.head()
# Out:
#    loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 0    10500.0    0.1719       375.35           RENT     66000.0
# 1    25000.0    0.2000       929.09       MORTGAGE    105000.0
# 2    20000.0    0.2000       529.88       MORTGAGE     56000.0
# 3    10000.0    0.1640       353.55           RENT     92000.0
# 4    22000.0    0.1474       520.39       MORTGAGE     52000.0
#
#   verification_status   issue_d loan_status pymnt_plan    dti  ...  \
# 0     Source Verified  Mar-2019    low_risk          n  27.24  ...
# 1            Verified  Mar-2019    low_risk          n  20.23  ...
# 2            Verified  Mar-2019    low_risk          n  24.26  ...
# 3            Verified  Mar-2019    low_risk          n  31.44  ...
# 4        Not Verified  Mar-2019    low_risk          n  18.76  ...
#
#    pct_tl_nvr_dlq  percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  \
# 0            85.7             100.0                   0.0        0.0
# ...

# %% [markdown]
# # Split the Data into Training and Testing

# %%
# Create our features
X = df.copy()
X = X.drop(columns="loan_status")
X = pd.get_dummies(X)

# Create our target
y = df["loan_status"]

# %%
#68817 loan IDS
X
# Out:
#        loan_amnt  int_rate  installment  annual_inc    dti  delinq_2yrs  \
# 0        10500.0    0.1719       375.35     66000.0  27.24          0.0
# 1        25000.0    0.2000       929.09    105000.0  20.23          0.0
# 2        20000.0    0.2000       529.88     56000.0  24.26          0.0
# 3        10000.0    0.1640       353.55     92000.0  31.44          0.0
# 4        22000.0    0.1474       520.39     52000.0  18.76          0.0
# ...          ...       ...          ...         ...    ...          ...
# 68812    10000.0    0.1502       346.76     26000.0   9.60          0.0
# 68813    12000.0    0.2727       368.37     63000.0  29.07          0.0
# 68814     5000.0    0.1992       185.62     52000.0  14.86          0.0
# 68815    40000.0    0.0646      1225.24    520000.0   9.96          0.0
# 68816    16000.0    0.1131       350.36     72000.0   7.02          2.0
#
#        inq_last_6mths  open_acc  pub_rec  revol_bal  ...  issue_d_Mar-2019  \
# ...

# %%
y
# Out:
# 0        low_risk
# 1        low_risk
# 2        low_risk
# 3        low_risk
# 4        low_risk
#            ...
# 68812    low_risk
# 68813    low_risk
# 68814    low_risk
# 68815    low_risk
# 68816    low_risk
# Name: loan_status, Length: 68817, dtype: object

# %%
X.describe()
# Out:
#           loan_amnt      int_rate   installment    annual_inc           dti  \
# count  68817.000000  68817.000000  68817.000000  6.881700e+04  68817.000000
# mean   16677.594562      0.127718    480.652863  8.821371e+04     21.778153
# std    10277.348590      0.048130    288.062432  1.155800e+05     20.199244
# min     1000.000000      0.060000     30.890000  4.000000e+01      0.000000
# 25%     9000.000000      0.088100    265.730000  5.000000e+04     13.890000
# 50%    15000.000000      0.118000    404.560000  7.300000e+04     19.760000
# 75%    24000.000000      0.155700    648.100000  1.040000e+05     26.660000
# max    40000.000000      0.308400   1676.230000  8.797500e+06    999.000000
#
#         delinq_2yrs  inq_last_6mths      open_acc       pub_rec  \
# count  68817.000000    68817.000000  68817.000000  68817.000000
# mean       0.217766        0.497697     12.587340      0.126030
# std        0.718367        0.758122      6.022869      0.336797
# ...

# %%
X.shape
# Out:
# (68817, 95)

# %%
# Check the balance of our target values
y.value_counts()
# Out:
# low_risk     68470
# high_risk      347
# Name: loan_status, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    random_state=1, 
                                                    stratify=y)
X_train.shape
# Out:
# (51612, 95)

# %%
y_train.shape
# Out:
# (51612,)

# %% [markdown]
# # Oversampling
#
# In this section, you will compare two oversampling algorithms to determine which algorithm results in the best performance. You will oversample the data using the naive random oversampling algorithm and the SMOTE algorithm. For each algorithm, be sure to complete the folliowing steps:
#
# 1. View the count of the target classes using `Counter` from the collections library.
# 3. Use the resampled data to train a logistic regression model.
# 3. Calculate the balanced accuracy score from sklearn.metrics.
# 4. Print the confusion matrix from sklearn.metrics.
# 5. Generate a classication report using the `imbalanced_classification_report` from imbalanced-learn.
#
# Note: Use a random state of 1 for each sampling algorithm to ensure consistency between tests

# %% [markdown]
# ### Naive Random Oversampling

# %%
# Resample the training data with the RandomOversampler

rs = RandomOverSampler(random_state=1)
X_resampled, y_resampled = rs.fit_resample(X_train, y_train)

# %%
Counter(y_resampled)
# Out:
# Counter({'low_risk': 51352, 'high_risk': 51352})

# %%
y_resampled.value_counts()
# Out:
# low_risk     51352
# high_risk    51352
# Name: loan_status, dtype: int64

# %%
# Train the Logistic Regression model using the resampled data

model = LogisticRegression(random_state=1)
model.fit(X_resampled, y_resampled)
# Out:
# LogisticRegression(random_state=1)

# %% [markdown]
# **Accuracy Score for Random Oversampling

# %%
# Calculated the balanced accuracy score

y_pred = model.predict(X_test)
Accuracy_randomoversampling = balanced_accuracy_score(y_test, y_pred)
Accuracy_randomoversampling
# Out:
# 0.6366972052004142

# %% [markdown]
# **confusion matrix for Random Oversampling

# %%
# Display the confusion matrix
from sklearn.metrics import confusion_matrix
cm1 = confusion_matrix(y_test, y_pred)
cm1
# Out:
# array([[   54,    33],
#        [ 5945, 11173]], dtype=int64)

# %%
Confusionmatrix_randomoversampling = pd.DataFrame(
    cm1, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"])

Confusionmatrix_randomoversampling
# Out:
#           Predicted 0  Predicted 1
# Actual 0           54           33
# Actual 1         5945        11173

# %% [markdown]
# **Imbalanced classification report for Random Oversampling

# %%
# Print the imbalanced classification report
from imblearn.metrics import classification_report_imbalanced
Random_Oversampling_report = print(classification_report_imbalanced(y_test, y_pred))
Random_Oversampling_report
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#   high_risk       0.01      0.62      0.65      0.02      0.64      0.40        87
#    low_risk       1.00      0.65      0.62      0.79      0.64      0.41     17118
#
# avg / total       0.99      0.65      0.62      0.79      0.64      0.41     17205

# %% [markdown]
# ### SMOTE Oversampling
# The challenge of working with imbalanced datasets is that most machine learning techniques will ignore, and in turn have poor performance on, the minority class, although typically it is performance on the minority class that is most important.One approach to addressing imbalanced datasets is to oversample the minority class.This is a type of data augmentation for the minority class and is referred to as the Synthetic Minority Oversampling Technique, or SMOTE for short.

# %%
# Resample the training data with SMOTE
X_resampled, y_resampled = SMOTE(random_state=1).fit_resample(X_train, y_train)

# %%
Counter(y_resampled)
# Out:
# Counter({'low_risk': 51352, 'high_risk': 51352})

# %%
# Train the Logistic Regression model using the resampled data
model = LogisticRegression(solver='lbfgs', random_state=1)

model.fit(X_resampled, y_resampled)
# Out:
# LogisticRegression(random_state=1)

# %% [markdown]
# **Accuracy Score for SMOTE Oversampling

# %%
# Calculated the balanced accuracy score
y_pred = model.predict(X_test)

Accuracy_SMOTE_Oversampling = balanced_accuracy_score(y_test, y_pred)
Accuracy_SMOTE_Oversampling
# Out:
# 0.6302712208564487

# %% [markdown]
# **Confusion matrix for SMOTE Oversampling

# %%
# Display the confusion matrix
from sklearn.metrics import confusion_matrix
cm2 = confusion_matrix(y_test, y_pred)
cm2
# Out:
# array([[   54,    33],
#        [ 6165, 10953]], dtype=int64)

# %%
Confusionmatrix_SMOTE = pd.DataFrame(
    cm2, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"])

Confusionmatrix_SMOTE
# Out:
#           Predicted 0  Predicted 1
# Actual 0           54           33
# Actual 1         6165        10953

# %% [markdown]
# **Imbalanced classification report for SMOTE Oversampling

# %%
# Print the imbalanced classification report
SMOTE_report = print(classification_report_imbalanced(y_test, y_pred))
SMOTE_report
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#   high_risk       0.01      0.62      0.64      0.02      0.63      0.40        87
#    low_risk       1.00      0.64      0.62      0.78      0.63      0.40     17118
#
# avg / total       0.99      0.64      0.62      0.78      0.63      0.40     17205

# %% [markdown]
# # Undersampling
#
# In this section, you will test an undersampling algorithms to determine which algorithm results in the best performance compared to the oversampling algorithms above. You will undersample the data using the Cluster Centroids algorithm and complete the folliowing steps:
#
# 1. View the count of the target classes using `Counter` from the collections library.
# 3. Use the resampled data to train a logistic regression model.
# 3. Calculate the balanced accuracy score from sklearn.metrics.
# 4. Print the confusion matrix from sklearn.metrics.
# 5. Generate a classication report using the `imbalanced_classification_report` from imbalanced-learn.
#
# Note: Use a random state of 1 for each sampling algorithm to ensure consistency between tests

# %%
# Resample the data using the ClusterCentroids resampler
# Warning: This is a large dataset, and this step may take some time to complete
X_resampled, y_resampled = ClusterCentroids(random_state=1).fit_resample(X_train, y_train)

# %%
Counter(y_resampled)
# Out:
# Counter({'high_risk': 260, 'low_risk': 260})

# %%
# Train the Logistic Regression model using the resampled data
model = LogisticRegression(solver='lbfgs', random_state=78)

model.fit(X_resampled, y_resampled)
# Out:
# LogisticRegression(random_state=78)

# %%
# Calculated the balanced accuracy score
y_pred = model.predict(X_test)

Accuracy_undersampling = balanced_accuracy_score(y_test, y_pred)
Accuracy_undersampling
# Out:
# 0.5182244139059107

# %%
# Display the confusion matrix
cm3 = confusion_matrix(y_test, y_pred)
cm3
# Out:
# array([[  50,   37],
#        [9214, 7904]], dtype=int64)

# %%
Confusionmatrix_undersampling = pd.DataFrame(
    cm3, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"])

Confusionmatrix_undersampling
# Out:
#           Predicted 0  Predicted 1
# Actual 0           50           37
# Actual 1         9214         7904

# %%
# Print the imbalanced classification report
Undersampling_report = print(classification_report_imbalanced(y_test, y_pred))
Undersampling_report
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#   high_risk       0.01      0.57      0.46      0.01      0.52      0.27        87
#    low_risk       1.00      0.46      0.57      0.63      0.52      0.26     17118
#
# avg / total       0.99      0.46      0.57      0.63      0.52      0.26     17205

# %% [markdown]
# # Combination (Over and Under) Sampling
#
# In this section, you will test a combination over- and under-sampling algorithm to determine if the algorithm results in the best performance compared to the other sampling algorithms above. You will resample the data using the SMOTEENN algorithm and complete the folliowing steps:
#
# 1. View the count of the target classes using `Counter` from the collections library.
# 3. Use the resampled data to train a logistic regression model.
# 3. Calculate the balanced accuracy score from sklearn.metrics.
# 4. Print the confusion matrix from sklearn.metrics.
# 5. Generate a classication report using the `imbalanced_classification_report` from imbalanced-learn.
#
# Note: Use a random state of 1 for each sampling algorithm to ensure consistency between tests

# %%
# Resample the training data with SMOTEENN
# Warning: This is a large dataset, and this step may take some time to complete
X_resampled, y_resampled = SMOTEENN(random_state=1).fit_resample(X_train, y_train)

# %%
Counter(y_resampled)
# Out:
# Counter({'high_risk': 51351, 'low_risk': 46389})

# %%
# Train the Logistic Regression model using the resampled data
model = LogisticRegression(solver='lbfgs', random_state=78)

model.fit(X_resampled, y_resampled)
# Out:
# LogisticRegression(random_state=78)

# %%
# Calculated the balanced accuracy score
y_pred = model.predict(X_test)

Accuracy_combisampling = balanced_accuracy_score(y_test, y_pred)
Accuracy_combisampling
# Out:
# 0.6248111485792329

# %%
# Display the confusion matrix
cm4 = confusion_matrix(y_test, y_pred)
cm4
# Out:
# array([[  62,   25],
#        [7926, 9192]], dtype=int64)

# %%
Confusionmatrix_combisampling = pd.DataFrame(
    cm4, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"])

Confusionmatrix_combisampling
# Out:
#           Predicted 0  Predicted 1
# Actual 0           62           25
# Actual 1         7926         9192

# %%
# Print the imbalanced classification report
Combisampling_report = print(classification_report_imbalanced(y_test, y_pred))
Combisampling_report
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#   high_risk       0.01      0.71      0.54      0.02      0.62      0.39        87
#    low_risk       1.00      0.54      0.71      0.70      0.62      0.38     17118
#
# avg / total       0.99      0.54      0.71      0.69      0.62      0.38     17205
